# %% [markdown]
# ### All are ML algorithym i will build on the top of this dataset. after that i will select best one of them algorithm.

# %%
# All are necessary libraries and classes are importing

import pandas as pd
import numpy as np
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
import xgboost
from xgboost import XGBClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import BernoulliNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import GaussianNB
import lazypredict
from lazypredict.Supervised import LazyClassifier
from lazypredict.Supervised import LazyRegressor
import joblib
import pickle
import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_rows',None)

# %%
scaled_data = pd.read_csv('Data/final_scaled_data.csv')
scaled_data.head()
# Out:
#    age  sex  TSH  TSH measured  pregnant  TT4 measured  T4U measured  FTI
# 0 0.27    0 0.01             1         0             1             0 0.28  \
# 1 0.55    1 0.00             1         0             1             1 0.30
# 2 0.84    0 0.00             1         0             1             0 0.28
# 3 0.84    0 0.00             1         0             1             1 0.17
# 4 0.21    0 0.00             1         0             1             1 0.35
#
#    FTI measured  I131 treatment  psych  on thyroxine  sick  labels
# 0             0               0      0             0     0       2  \
# 1             1               0      0             0     0       2
# 2             0               0      0             1     0       2
# 3             1               0      0             0     0       2
# 4             1               0      0             1     0       2
#
#    continues_target
# 0           1442.00
# 1           2965.00
# 2            806.00
# 3           2807.00
# ...

# %%
without_scaled_data = pd.read_csv('Data/final_without_scaled_data.csv')
without_scaled_data.head()
# Out:
#     age  sex  TSH  TSH measured  pregnant  TT4 measured  T4U measured    FTI
# 0 23.00    0 4.10             1         0             1             0 110.47  \
# 1 46.00    1 0.98             1         0             1             1 120.00
# 2 70.00    0 0.16             1         0             1             0 110.47
# 3 70.00    0 0.72             1         0             1             1  70.00
# 4 18.00    0 0.03             1         0             1             1 141.00
#
#    FTI measured  I131 treatment  psych  on thyroxine  sick  labels
# 0             0               0      0             0     0       2  \
# 1             1               0      0             0     0       2
# 2             0               0      0             1     0       2
# 3             1               0      0             0     0       2
# 4             1               0      0             1     0       2
#
#    continues_target
# 0           1442.00
# 1           2965.00
# 2            806.00
# ...

# %%
df = without_scaled_data[without_scaled_data['age']<84]
df.head()
# Out:
#     age  sex  TSH  TSH measured  pregnant  TT4 measured  T4U measured    FTI
# 0 23.00    0 4.10             1         0             1             0 110.47  \
# 1 46.00    1 0.98             1         0             1             1 120.00
# 2 70.00    0 0.16             1         0             1             0 110.47
# 3 70.00    0 0.72             1         0             1             1  70.00
# 4 18.00    0 0.03             1         0             1             1 141.00
#
#    FTI measured  I131 treatment  psych  on thyroxine  sick  labels
# 0             0               0      0             0     0       2  \
# 1             1               0      0             0     0       2
# 2             0               0      0             1     0       2
# 3             1               0      0             0     0       2
# 4             1               0      0             1     0       2
#
#    continues_target
# 0           1442.00
# 1           2965.00
# 2            806.00
# ...

# %%
df[df['labels']==1]
# Out:
#        age  sex   TSH  TSH measured  pregnant  TT4 measured  T4U measured
# 26   25.00    0  0.30             1         0             1             0  \
# 54   77.00    1  2.00             1         0             1             1
# 85   31.00    0  1.30             1         0             1             1
# 94   26.00    0  2.00             1         0             1             1
# 119  23.00    0  0.02             1         0             1             1
# 125  30.00    0  2.70             1         1             1             1
# 129  29.00    0  1.60             1         0             1             1
# 133  80.00    1  1.30             1         0             1             1
# 196  83.00    1  1.60             1         0             1             1
# 198  32.00    0  0.03             1         1             1             1
# 212  34.00    0 26.00             1         0             1             1
# 233  47.00    0  0.01             1         0             1             1
# ...

# %%
scaled_data.shape
# Out:
# (3682, 15)

# %%
df.shape
# Out:
# (3682, 15)

# %% [markdown]
# ## Model Building with Lazypredict on scaling data,
#     lazypredict is a python which is used for as like the survey. to get
#     general overview of  our model building in a fews steps. it will train all the
#     models on the specific dataset. and gives the accuracy,precision,recall as an output

# %%
scaled_data.head()
# Out:
#    age  sex  TSH  TSH measured  pregnant  TT4 measured  T4U measured  FTI
# 0 0.27    0 0.01             1         0             1             0 0.28  \
# 1 0.55    1 0.00             1         0             1             1 0.30
# 2 0.84    0 0.00             1         0             1             0 0.28
# 3 0.84    0 0.00             1         0             1             1 0.17
# 4 0.21    0 0.00             1         0             1             1 0.35
#
#    FTI measured  I131 treatment  psych  on thyroxine  sick  labels
# 0             0               0      0             0     0       2  \
# 1             1               0      0             0     0       2
# 2             0               0      0             1     0       2
# 3             1               0      0             0     0       2
# 4             1               0      0             1     0       2
#
#    continues_target
# 0           1442.00
# 1           2965.00
# 2            806.00
# 3           2807.00
# ...

# %%
x = scaled_data.drop(['labels','continues_target'],axis = 1)
y = scaled_data['labels']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
lazyclasifier = LazyClassifier(verbose=0,ignore_warnings=True,custom_metric=accuracy_score)

# %%
models , predictions = lazyclasifier.fit(x_train,x_test,y_train,y_test)
# Out:
#  93%|█████████▎| 27/29 [00:04<00:00,  7.13it/s]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001349 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 513
# [LightGBM] [Info] Number of data points in the train set: 2945, number of used features: 13
# [LightGBM] [Info] Start training from score -5.502957
# [LightGBM] [Info] Start training from score -3.105062
# [LightGBM] [Info] Start training from score -0.050132
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 100%|██████████| 29/29 [00:05<00:00,  5.09it/s]

# %% [markdown]
# ### result of models by lazypredict

# %%
models1 = pd.DataFrame(models)
models1
# Out:
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score
# Model
# NearestCentroid                    0.42               0.53    None      0.59  \
# GaussianNB                         0.18               0.45    None      0.30
# BaggingClassifier                  0.98               0.41    None      0.97
# DecisionTreeClassifier             0.94               0.40    None      0.95
# PassiveAggressiveClassifier        0.88               0.40    None      0.92
# SVC                                0.98               0.39    None      0.97
# SGDClassifier                      0.98               0.39    None      0.97
# RidgeClassifierCV                  0.98               0.39    None      0.97
# RidgeClassifier                    0.98               0.39    None      0.97
# LinearDiscriminantAnalysis         0.98               0.39    None      0.97
# CalibratedClassifierCV             0.98               0.39    None      0.97
# ...

# %% [markdown]
# ### Lazypredict model on without scaling data

# %%
x = without_scaled_data.drop(['labels','continues_target'],axis = 1)
y = without_scaled_data['labels']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
lazyclasifier2 = LazyClassifier(verbose=0,ignore_warnings=True,custom_metric=accuracy_score)

# %%
models2 , predictions2 = lazyclasifier2.fit(x_train,x_test,y_train,y_test)
# Out:
# 100%|██████████| 29/29 [00:04<00:00,  6.63it/s]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000125 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 519
# [LightGBM] [Info] Number of data points in the train set: 3016, number of used features: 13
# [LightGBM] [Info] Start training from score -5.613791
# [LightGBM] [Info] Start training from score -3.191405
# [LightGBM] [Info] Start training from score -0.045794
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %%
pd.DataFrame(models2)
# Out:
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score
# Model
# Perceptron                         0.92               0.43    None      0.93  \
# BaggingClassifier                  0.95               0.39    None      0.95
# KNeighborsClassifier               0.96               0.38    None      0.95
# RandomForestClassifier             0.96               0.38    None      0.95
# NearestCentroid                    0.35               0.38    None      0.51
# SVC                                0.96               0.37    None      0.95
# LinearSVC                          0.96               0.37    None      0.95
# BernoulliNB                        0.96               0.37    None      0.95
# CalibratedClassifierCV             0.96               0.37    None      0.95
# RidgeClassifierCV                  0.96               0.37    None      0.95
# RidgeClassifier                    0.96               0.37    None      0.95
# ...

# %% [markdown]
# ### top 5 models which are trained on this data

# %%
models1.sort_values(by = 'Balanced Accuracy',ascending=False)[0:5]
# Out:
#                              Accuracy  Balanced Accuracy ROC AUC  F1 Score
# Model
# NearestCentroid                  0.42               0.53    None      0.59  \
# GaussianNB                       0.18               0.45    None      0.30
# BaggingClassifier                0.98               0.41    None      0.97
# DecisionTreeClassifier           0.94               0.40    None      0.95
# PassiveAggressiveClassifier      0.88               0.40    None      0.92
#
#                              accuracy_score  Time Taken
# Model
# NearestCentroid                        0.42        0.02
# GaussianNB                             0.18        0.02
# BaggingClassifier                      0.98        0.17
# DecisionTreeClassifier                 0.94        0.03
# PassiveAggressiveClassifier            0.88        0.04

# %% [markdown]
# ## Model Building with Hyperparameter turning on scaled data

# %%
model_and_parameter ={

"Logistic_Regression" :{
                        "model" : LogisticRegression(),
                        "param" : {'penalty':['l1', 'l2', 'elasticnet'],
                                    'solver' : ['newton-cg', 'lbfgs', 'liblinear']}
                       },

"Decision_Tree" :{
                        "model" : DecisionTreeClassifier(),
                        "param" : {'criterion' : ["gini", "entropy","log_loss"],
                                  'splitter' : ["best", "random"],
                                  'max_depth':range(4,16,1),
                                  'min_samples_leaf':range(2,8,1),
                                  'min_samples_split':range(2,8,1)}
                                  
                 },

"SVC" : {
                        "model" : SVC(),
                        "param" : {'C' :[1.0],
                                   'kernel' : ['linear', 'poly', 'rbf'],
                                   'gamma': ['scale','auto']}
                                  
       },

"KNeighborsClassifier" : {
                        "model" : KNeighborsClassifier(),
                        "param" : {'n_neighbors' : [3,5,7,9],
                                  'algorithm' : ['auto', 'ball_tree', 'kd_tree', 'brute'],
                                  'metric':['euclidian','minkowski']}
                                   
                        },

"GaussianNB" :  {
                    "model" : GaussianNB(),
                    "param" : {}
                 },


"RandomForestClassifier" :{
                    "model" : RandomForestClassifier(),
                    "param" : {'criterion' : ["gini", "entropy"],
                            'n_estimators' : [80,100,120,135,150],
                            'max_depth':range(4,16,1),
                            'min_samples_leaf':range(1,8,1),
                            'min_samples_split':range(2,8,1)
                              }
                      },

 "AdaBoostClassifier" :{
                    "model" : AdaBoostClassifier(),
                    "param" : {'n_estimators' : [10,50,100],
                                'learning_rate':[1.0,0.02,0.04,0.4],}
                      },

"GradientBoostingClassifier" :{
                    "model" : GradientBoostingClassifier(),
                    "param" : {'n_estimators' : [10,50,100],
                              'learning_rate':[1.0,0.02,0.04,0.4],
                              'criterion' : ['friedman_mse', 'squared_error', 'mse'], 
                              'min_samples_split':range(3,7,1),
                              'min_samples_leaf':range(1,7,1),
                              'max_depth':range(3,6,1)}
                      },

"XGBClassifier" :{
                    "model" : XGBClassifier(),
                    "param" : {}
}

}

# %% [markdown]
# ### due to more computation power required ,i skipped some of them hyperparameters

# %%
model_and_parameter ={

"Logistic_Regression" :{
                        "model" : LogisticRegression(),
                        "param" : {'penalty':['l1', 'l2', 'elasticnet'],
                                    'solver' : ['newton-cg', 'lbfgs', 'liblinear']}
                       },

"Decision_Tree" :{
                        "model" : DecisionTreeClassifier(),
                        "param" : {'criterion' : ["gini", "entropy","log_loss"],
                                  'splitter' : ["best", "random"],
                                  'max_depth':range(4,16,1),
                                  'min_samples_leaf':range(2,8,1),
                                  'min_samples_split':range(2,8,1)}
                                  
                 },

"SVC" : {
                        "model" : SVC(),
                        "param" : {'C' :[1.0],
                                   'kernel' : ['linear', 'poly', 'rbf'],
                                   'gamma': ['scale','auto']}
                                  
       },

"KNeighborsClassifier" : {
                        "model" : KNeighborsClassifier(),
                        "param" : {'n_neighbors' : [3,5,7,9],
                                  'algorithm' : ['auto', 'ball_tree', 'kd_tree', 'brute'],
                                  'metric':['euclidian','minkowski']}
                                   
                        },

"GaussianNB" :  {
                    "model" : GaussianNB(),
                    "param" : {}
                 },


"RandomForestClassifier" :{
                    "model" : RandomForestClassifier(),
                    "param" : {'criterion' : ["gini", "entropy"],
                            'n_estimators' : [80,100,120,135,150]
                            
                              }
                      },

 "AdaBoostClassifier" :{
                    "model" : AdaBoostClassifier(),
                    "param" : {'n_estimators' : [10,50,100],
                                'learning_rate':[1.0,0.02,0.04,0.4],}
                      },

"GradientBoostingClassifier" :{
                    "model" : GradientBoostingClassifier(),
                    "param" : {'n_estimators' : [10,50,100],
                             }
                      },

"XGBClassifier" :{
                    "model" : XGBClassifier(),
                    "param" : {}
}

}

# %% [markdown]
# ### Train test split on scaled data

# %%
scaled_data.head()
# Out:
#    age  sex  TSH  TSH measured  pregnant  TT4 measured  T4U measured  FTI
# 0 0.27    0 0.01             1         0             1             0 0.28  \
# 1 0.55    1 0.00             1         0             1             1 0.30
# 2 0.84    0 0.00             1         0             1             0 0.28
# 3 0.84    0 0.00             1         0             1             1 0.17
# 4 0.21    0 0.00             1         0             1             1 0.35
#
#    FTI measured  I131 treatment  psych  on thyroxine  sick  labels
# 0             0               0      0             0     0       2  \
# 1             1               0      0             0     0       2
# 2             0               0      0             1     0       2
# 3             1               0      0             0     0       2
# 4             1               0      0             1     0       2
#
#    continues_target
# 0           1442.00
# 1           2965.00
# 2            806.00
# 3           2807.00
# ...

# %%
len(scaled_data.columns)
# Out:
# 15

# %%
x = scaled_data.drop(['labels','continues_target'],axis = 1)
y = scaled_data['labels']
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape
# Out:
# (2945, 13)

# %%
# By the gridsearchCV

Scores = []
for model_name ,model_param in model_and_parameter.items():
    gs = GridSearchCV(model_param['model'],model_param['param'],cv = 5,return_train_score=False)
    gs.fit(x_train,y_train)
    Scores.append({'Model': model_name,
                 'Best_Score' : gs.best_score_,
                 'Best_Parameter' : gs.best_params_})
    best_model_of_algo = gs.best_estimator_
    joblib.dump(best_model_of_algo,'models/ML_models/'+model_name+str(int(round(gs.best_score_,2)*100))+'.lb')     # to save the best model of algorithm

# %%
model_info = pd.DataFrame(Scores,columns=['Model','Best_Score','Best_Parameter'])
model_info.sort_values(by='Best_Score',ascending=False)
# Out:
#                         Model  Best_Score
# 1               Decision_Tree        0.96  \
# 2                         SVC        0.95
# 5      RandomForestClassifier        0.95
# 7  GradientBoostingClassifier        0.95
# 0         Logistic_Regression        0.95
# 6          AdaBoostClassifier        0.95
# 3        KNeighborsClassifier        0.95
# 8               XGBClassifier        0.95
# 4                  GaussianNB        0.17
#
#                                       Best_Parameter
# 1  {'criterion': 'gini', 'max_depth': 7, 'min_sam...
# 2      {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
# 5          {'criterion': 'gini', 'n_estimators': 80}
# 7                               {'n_estimators': 10}
# 0           {'penalty': 'l1', 'solver': 'liblinear'}
# 6         {'learning_rate': 1.0, 'n_estimators': 10}
# 3  {'algorithm': 'auto', 'metric': 'minkowski', '...
# 8                                                 {}
# 4                                                 {}

# %%
model_info.sort_values(by='Best_Score',ascending=False).iloc[0,2]        # best parameter
# Out:
# {'criterion': 'gini',
#  'max_depth': 7,
#  'min_samples_leaf': 6,
#  'min_samples_split': 5,
#  'splitter': 'random'}

# %% [markdown]
# ### Prediction & model evaluation

# %%
x_train.head()
# Out:
#       age  sex  TSH  TSH measured  pregnant  TT4 measured  T4U measured  FTI
# 1001 0.23    1 0.01             0         0             1             0 0.28  \
# 2493 0.84    1 0.00             1         0             1             1 0.26
# 1284 0.93    0 0.00             1         0             0             0 0.28
# 1151 0.51    0 0.00             1         0             1             1 0.46
# 3201 0.82    0 0.01             1         0             1             1 0.23
#
#       FTI measured  I131 treatment  psych  on thyroxine  sick
# 1001             0               0      0             0     0
# 2493             1               0      0             0     0
# 1284             0               0      0             0     0
# 1151             1               0      0             1     0
# 3201             1               0      0             0     0

# %%
x_train.columns
# Out:
# Index(['age', 'sex', 'TSH', 'TSH measured', 'pregnant', 'TT4 measured',
#        'T4U measured', 'FTI', 'FTI measured', 'I131 treatment', 'psych',
#        'on thyroxine', 'sick'],
#       dtype='object')

# %%
dtc = joblib.load('models\ML_models\KNeighborsClassifier95.lb')       #load the model
y_pred = dtc.predict(x_test)

# %%
y_pred
# Out:
# array([2, 2, 2, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
# ...

# %%
accuracy_score(y_test,y_pred)           ## good accuracy on testing data
# Out:
# 0.9755766621438263

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[  0,   0,   1],
#        [  0,   2,  15],
#        [  0,   2, 717]], dtype=int64)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.50      0.12      0.19        17
#            2       0.98      1.00      0.99       719
#
#     accuracy                           0.98       737
#    macro avg       0.49      0.37      0.39       737
# weighted avg       0.97      0.98      0.97       737

# %%
pd.DataFrame(y_pred)[0].value_counts()
# Out:
# 0
# 2    733
# 1      4
# Name: count, dtype: int64

# %%
pd.DataFrame(y_test)['labels'].value_counts()
# Out:
# labels
# 2    719
# 1     17
# 0      1
# Name: count, dtype: int64

# %%
XGBC = joblib.load('models/ML_models/Decision_Tree96.lb')

# %%
pred2 = XGBC.predict(x_test)

# %%
accuracy_score(y_test,pred2)
# Out:
# 0.9755766621438263

# %%
pd.DataFrame(y_test)['labels'].value_counts()
# Out:
# labels
# 2    719
# 1     17
# 0      1
# Name: count, dtype: int64

# %%
pd.DataFrame(pred2)[0].value_counts()
# Out:
# 0
# 2    733
# 1      4
# Name: count, dtype: int64

# %%
lgr = joblib.load('models/ML_models/Logistic_Regression95.lb')

# %%
pred3 = lgr.predict(x_test)

# %%
accuracy_score(y_test,pred3)
# Out:
# 0.9769335142469471

# %%
pd.DataFrame(y_test)['labels'].value_counts()
# Out:
# labels
# 2    719
# 1     17
# 0      1
# Name: count, dtype: int64

# %%
pd.DataFrame(pred3)[0].value_counts()
# Out:
# 0
# 2    734
# 1      3
# Name: count, dtype: int64

# %% [markdown]
# ### model  building completed,
# this data was not in a linearFashion that,s why i got the maximum accuracy <br>
# by the DecissionTreeClassifier. so i am selecting this model for the final model.
